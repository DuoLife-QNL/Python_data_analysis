# %%
from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.charts import Geo
from pyecharts.render import make_snapshot
from snapshot_phantomjs import snapshot
from pyecharts.globals import ChartType
from pyecharts.faker import Collector, Faker
import random
import matplotlib
# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib import font_manager as fm
import pandas as pd
import imageio
from mpl_toolkits.mplot3d import Axes3D
import math
import numpy as np

# %% [markdown]
# ## 作业8

# %% [markdown]
# ### 调整顺序角度，并更改字体大小

# %%
fig1 = plt.figure()
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
label_list = ['保送本校读研','保送外校读研', '本校本硕博连读', '出国', '考研']
size = [12, 7, 5, 10, 2]
explode = [0.2, 0, 0, 0, 0]
patches, texts, autotexts = plt.pie(size, explode = explode, labels = label_list, labeldistance = 1.1, autopct='%1.1f%%',shadow=True, startangle = 0, pctdistance = 0.6)
proptease = fm.FontProperties()
proptease.set_size('large')
plt.setp(texts, fontproperties = proptease)
plt.setp(autotexts, fontproperties = proptease)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 尝试合适的数据项数

# %% [markdown]
# 生成在(0, 9)之间的随机整数并追加到数据末尾；最后发现使得可视化程度较高的总项数上限大概在12左右

# %%
fig2 = plt.figure()
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
label_list = ['保送本校读研','保送外校读研', '本校本硕博连读', '出国', '考研']
max_item = 7
size = [12, 7, 5, 10, 2]
explode = [0.2, 0, 0, 0, 0]
for x in range(0, max_item):
    label_list.append('其它' + str(x + 1))
    size.append(random.randint(1,9))
    explode.append(0)
patches, texts, autotexts = plt.pie(size, explode = explode, labels = label_list, labeldistance = 1.1, autopct='%1.1f%%',shadow=True, startangle = 90, pctdistance = 0.6)
proptease = fm.FontProperties()
# proptease.set_size('large')
plt.setp(texts, fontproperties = proptease)
plt.setp(autotexts, fontproperties = proptease)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## 作业9
# 导入之前对原始数据文件的列明做了一些处理

# %%
college = pd.read_csv('../data/college.csv')

# %%
class Data:
    provinces = list(college.loc[:, '省/市'])
    college_211_num = map(int, list(college.loc[:, '211&985大学数量']))
    college_public_num = map(int, list(college.loc[:, '公办本科大学数量']))
    def values(start: int = 20, end : int = 150):
        return [random.randint(start, end) for _ in range(32)]

# %%
m1 = (
    Map()
    .add('211&985大学数量', [list(z) for z in zip(Data.provinces, Data.college_211_num)], 'china')
    .set_global_opts(
        title_opts=opts.TitleOpts(title="各省211&985大学数量"),
        visualmap_opts = opts.VisualMapOpts(min_ = 0, max_ = 20)
    )
    .set_series_opts(label_opts = opts.LabelOpts(is_show = True))
)
m2 = (
    Map()
    .add('公办本科大学数量', [list(z) for z in zip(Data.provinces, Data.college_public_num)], 'china')
    .set_global_opts(
        title_opts=opts.TitleOpts(title="各省公办本科大学数量"),
        visualmap_opts = opts.VisualMapOpts(min_ = 0, max_ = 50)
    )
    .set_series_opts(label_opts = opts.LabelOpts(is_show = True))
)

# %%
m1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="e01547bf2882487bb42568e1cf31161c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_e01547bf2882487bb42568e1cf31161c = echarts.init(
#                     document.getElementById('e01547bf2882487bb42568e1cf31161c'), 'white', {renderer: 'canvas'});
#                 var option_e01547bf2882487bb42568e1cf31161c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "211&985\u5927\u5b66\u6570\u91cf",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 26
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 9
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 1
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {},
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "211&985\u5927\u5b66\u6570\u91cf"
#             ],
#             "selected": {
#                 "211&985\u5927\u5b66\u6570\u91cf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5404\u7701211&985\u5927\u5b66\u6570\u91cf"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 20,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140
#     }
# };
#                 chart_e01547bf2882487bb42568e1cf31161c.setOption(option_e01547bf2882487bb42568e1cf31161c);
#         });
#     </script>

# %%
m2.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="5a066e6c8c084ee9aaf5c483b1b9efdd" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_5a066e6c8c084ee9aaf5c483b1b9efdd = echarts.init(
#                     document.getElementById('5a066e6c8c084ee9aaf5c483b1b9efdd'), 'white', {renderer: 'canvas'});
#                 var option_5a066e6c8c084ee9aaf5c483b1b9efdd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u516c\u529e\u672c\u79d1\u5927\u5b66\u6570\u91cf",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 37
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 41
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 44
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 34
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 36
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 19
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 31
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 24
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 23
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 36
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 45
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 34
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 22
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 22
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 32
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 17
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 17
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 14
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 22
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 26
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 13
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 25
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 60
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 31
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 3
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {},
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u516c\u529e\u672c\u79d1\u5927\u5b66\u6570\u91cf"
#             ],
#             "selected": {
#                 "\u516c\u529e\u672c\u79d1\u5927\u5b66\u6570\u91cf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5404\u7701\u516c\u529e\u672c\u79d1\u5927\u5b66\u6570\u91cf"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 50,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140
#     }
# };
#                 chart_5a066e6c8c084ee9aaf5c483b1b9efdd.setOption(option_5a066e6c8c084ee9aaf5c483b1b9efdd);
#         });
#     </script>

# %% [markdown]
# ## 作业10
# 随机生成天气数据（省份：辽宁）

# %%
class Data:
    liaoning_city = ['沈阳市', '大连市', '鞍山市', '抚顺市', '本溪市', '丹东市', '锦州市', '营口市', '阜新市', '辽阳市', '盘锦市', '铁岭市', '朝阳市', '葫芦岛市']
    def values(start: int = 30, end : int = 40) -> list:
        return [random.randint(start, end) for _ in range(21)]

def geo_liaoning(title) -> Geo:    
    m = (
        Geo()
        .add_schema(maptype = '辽宁')
        .add(
            title, [list(z) for z in zip(Data.liaoning_city, Data.values())],
            type_ = ChartType.HEATMAP
        )
        .set_global_opts(
            visualmap_opts = opts.VisualMapOpts(max_ = 42, is_piecewise = True),
            title_opts = opts.TitleOpts(title = '辽宁省8月各地级市温度变化情况')
        )
    )
    return m

# %%
img_path = 'img/'
for i in range(1, 32):
    str_date = 'Aug ' + str(i)
    make_snapshot(snapshot, geo_liaoning(str_date).render(), img_path + str(i) + '.png', pixel_ratio = 3)

# %% [markdown]
# ### 输出gif文件（见压缩文件内）

# %%
images = []
filenames = []
for i in range(1, 32):
    filenames.append(img_path + str(i) + '.png')
for filename in filenames:
    images.append(imageio.imread(filename))
imageio.mimsave(img_path + 'temperature.gif', images)

# %% [markdown]
# ## 作业11
# 生成阶梯

# %%
fig3 = plt.figure()
ax = fig3.add_subplot(1, 1, 1, projection= '3d')
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

x = []
y = []
for i in list(range(0, 25)):
    y.append(i // 5)
    x.append(i % 5)
z = [1, 2, 3, 4, 5, 16, 17, 18, 19, 6, 15, 24, 25, 20, 7, 14, 23, 22, 21, 8, 13, 12, 11, 10, 9]

bottom = np.zeros_like(z)
width = depth = 0.8
ax.bar3d(x, y, bottom, width, depth, z)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## 作业12
# 生成金字塔

# %% [markdown]
# ### 生成一个金字塔

# %%
fig3 = plt.figure()
ax = fig3.add_subplot(1, 1, 1, projection= '3d')
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

x = np.linspace(-1, 1, 100)
y = np.linspace(-1, -1, 100)
z = 0 * x
ax.plot(x, y, z, 'r')
x_ = y
y_ = x
ax.plot(x_, y_, z, 'r')
x = np.linspace(-1, 1, 100)
y = np.linspace(1, 1, 100)
z = 0 * x
ax.plot(x, y, z, 'r')
x_ = y
y_ = x
ax.plot(x_, y_, z, 'r')
x = np.linspace(-1, 0, 100)
y = x
z = x + 1
ax.plot(x, y, z, 'r')
x = np.linspace(0, 1, 100)
y = -x
z = -x + 1
ax.plot(x, y, z, 'r')
x = np.linspace(0, 1, 100)
y = x
z = -x + 1
ax.plot(x, y, z, 'r')
x = np.linspace(-1, 0, 100)
y = -x
z = x + 1
ax.plot(x, y, z, 'r')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 生成两个金字塔

# %%
fig4 = plt.figure()
ax = fig4.add_subplot(1, 1, 1, projection= '3d')
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

x = np.linspace(-1, 1, 100)
y = np.linspace(-1, -1, 100)
z = 0 * x
ax.plot(x, y, z, 'r')
x_ = y
y_ = x
ax.plot(x_, y_, z, 'r')
x = np.linspace(-1, 1, 100)
y = np.linspace(1, 1, 100)
z = 0 * x
ax.plot(x, y, z, 'r')
x_ = y
y_ = x
ax.plot(x_, y_, z, 'r')
x = np.linspace(-1, 0, 100)
y = x
z = x + 1
ax.plot(x, y, z, 'r')
x = np.linspace(0, 1, 100)
y = -x
z = -x + 1
ax.plot(x, y, z, 'r')
x = np.linspace(0, 1, 100)
y = x
z = -x + 1
ax.plot(x, y, z, 'r')
x = np.linspace(-1, 0, 100)
y = -x
z = x + 1
ax.plot(x, y, z, 'r')
x = np.linspace(-1, 0, 100)
y = x
z = -x - 1
ax.plot(x, y, z, 'b')
x = np.linspace(0, 1, 100)
y = -x
z = x - 1
ax.plot(x, y, z, 'b')
x = np.linspace(0, 1, 100)
y = x
z = x - 1
ax.plot(x, y, z, 'b')
x = np.linspace(-1, 0, 100)
y = -x
z = - x - 1
ax.plot(x, y, z, 'b')
# Out:
# <img src="data:image/png;base64,..." width="524">

# %% [markdown]
# ## 作业13
# 生成散点图

# %%
plt.style.use('default')
fig5 = plt.figure()
ax = fig5.add_subplot(1, 1, 1, projection= '3d')
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

x = np.random.randint(-100, 100, 5000)
y = np.random.randint(-100, 100, 5000)
z = x**2 + y**2 -20000
ax.scatter(x, y, z, c = 'r', s = 2, marker = '^')
x = np.random.randint(-100, 100, 5000)
y = np.random.randint(-100, 100, 5000)
z = -(x**2 + y**2) +20000
ax.scatter(x, y, z, c = 'b', s = 2, marker = '^')
# Out:
# <img src="data:image/png;base64,..." width="708">
